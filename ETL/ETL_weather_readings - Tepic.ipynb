# %% [markdown]
# # **ETL**

# %%
# Main libraries

import requests 
import os 
import pandas as pd  
import numpy as np
from datetime import datetime
from meteostat import Point, Daily, Hourly
import sqlalchemy
from sqlalchemy import create_engine

# %%
pd.set_option('display.max_rows', 5)

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## **Weather Readings: Tepic**

# %% [markdown]
# **Method**: Meteostat Python Library

# %%
Tepic_latitude = 21.5083   
Tepic_longitude = -104.893    
Tepic = Point(Tepic_latitude, Tepic_longitude)

# %% [markdown]
# **Daily data**

# %%
# Set time period
start = datetime(1994, 1, 1)
end = datetime(2024, 11, 3)

# Get daily data
Tepic_daily = Daily(Tepic, start, end)
Tepic_daily = Tepic_daily.fetch()
Tepic_daily
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 1994-01-01  19.6   NaN   NaN   0.0   NaN    NaN   NaN   NaN     NaN   NaN
# 1994-01-02  19.5   NaN   NaN   0.0   NaN    NaN   NaN   NaN     NaN   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-11-02  21.5  10.0  29.0   0.0   NaN  249.0   6.6   NaN  1015.3   NaN
# 2024-11-03  20.6  11.0  29.0   0.0   NaN  236.0   6.7   NaN  1013.7   NaN
#
# [11265 rows x 10 columns]

# %% [markdown]
# **Hourly data**

# %%
# Data exploration
Tepic_hourly = Hourly(Tepic, start, end)
Tepic_hourly = Tepic_hourly.fetch()
Tepic_hourly
# Out:
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 1994-01-01 00:00:00  24.0  12.0  47.0   NaN   NaN  360.0  14.8   NaN  1000.1
# 1994-01-01 01:00:00  21.0  15.1  69.0   NaN   NaN  360.0   9.0   NaN  1000.1
# ...                   ...   ...   ...   ...   ...    ...   ...   ...     ...
# 2024-11-02 23:00:00  24.0  19.9  78.0   0.0   NaN  360.0  11.0   NaN  1015.0
# 2024-11-03 00:00:00  22.0  16.1  69.0   0.0   NaN  325.0   6.5   NaN  1015.0
#
#                      tsun  coco
# time
# 1994-01-01 00:00:00   NaN   NaN
# 1994-01-01 01:00:00   NaN   NaN
# ...                   ...   ...
# 2024-11-02 23:00:00   NaN   1.0
# 2024-11-03 00:00:00   NaN   1.0
#
# [270337 rows x 11 columns]

# %%
# Adding columns according to the ER diagram 
Tepic_hourly['date']=Tepic_hourly.index.date 
Tepic_hourly['time']=Tepic_hourly.index.time 
Tepic_hourly['city']= 'Querétaro'
Tepic_hourly
# Out:
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 1994-01-01 00:00:00  24.0  12.0  47.0   NaN   NaN  360.0  14.8   NaN  1000.1
# 1994-01-01 01:00:00  21.0  15.1  69.0   NaN   NaN  360.0   9.0   NaN  1000.1
# ...                   ...   ...   ...   ...   ...    ...   ...   ...     ...
# 2024-11-02 23:00:00  24.0  19.9  78.0   0.0   NaN  360.0  11.0   NaN  1015.0
# 2024-11-03 00:00:00  22.0  16.1  69.0   0.0   NaN  325.0   6.5   NaN  1015.0
#
#                      tsun  coco        date      time       city
# time
# 1994-01-01 00:00:00   NaN   NaN  1994-01-01  00:00:00  Querétaro
# 1994-01-01 01:00:00   NaN   NaN  1994-01-01  01:00:00  Querétaro
# ...                   ...   ...         ...       ...        ...
# 2024-11-02 23:00:00   NaN   1.0  2024-11-02  23:00:00  Querétaro
# 2024-11-03 00:00:00   NaN   1.0  2024-11-03  00:00:00  Querétaro
#
# [270337 rows x 14 columns]

# %%
# Renaming columns according to the ER diagram 
Tepic_hourly = Tepic_hourly.rename(columns={'temp':'temperature','coco':'code', 'dwpt':'dew_point', 'pres':'pressure', 'wspd':'wind_speed','rhum':'relative_humidity'})
Tepic_hourly
# Out:
#                      temperature  dew_point  relative_humidity  prcp  snow  \
# time
# 1994-01-01 00:00:00         24.0       12.0               47.0   NaN   NaN
# 1994-01-01 01:00:00         21.0       15.1               69.0   NaN   NaN
# ...                          ...        ...                ...   ...   ...
# 2024-11-02 23:00:00         24.0       19.9               78.0   0.0   NaN
# 2024-11-03 00:00:00         22.0       16.1               69.0   0.0   NaN
#
#                       wdir  wind_speed  wpgt  pressure  tsun  code  \
# time
# 1994-01-01 00:00:00  360.0        14.8   NaN    1000.1   NaN   NaN
# 1994-01-01 01:00:00  360.0         9.0   NaN    1000.1   NaN   NaN
# ...                    ...         ...   ...       ...   ...   ...
# 2024-11-02 23:00:00  360.0        11.0   NaN    1015.0   NaN   1.0
# 2024-11-03 00:00:00  325.0         6.5   NaN    1015.0   NaN   1.0
#
#                            date      time       city
# time
# 1994-01-01 00:00:00  1994-01-01  00:00:00  Querétaro
# 1994-01-01 01:00:00  1994-01-01  01:00:00  Querétaro
# ...                         ...       ...        ...
# 2024-11-02 23:00:00  2024-11-02  23:00:00  Querétaro
# 2024-11-03 00:00:00  2024-11-03  00:00:00  Querétaro
#
# [270337 rows x 14 columns]

# %%
# Filtering needed columns
Tepic_weather_readings=Tepic_hourly[['date','time','temperature','dew_point','pressure','wind_speed', 'relative_humidity']]
Tepic_weather_readings
# Out:
#                            date      time  temperature  dew_point  pressure  \
# time
# 1994-01-01 00:00:00  1994-01-01  00:00:00         24.0       12.0    1000.1
# 1994-01-01 01:00:00  1994-01-01  01:00:00         21.0       15.1    1000.1
# ...                         ...       ...          ...        ...       ...
# 2024-11-02 23:00:00  2024-11-02  23:00:00         24.0       19.9    1015.0
# 2024-11-03 00:00:00  2024-11-03  00:00:00         22.0       16.1    1015.0
#
#                      wind_speed  relative_humidity
# time
# 1994-01-01 00:00:00        14.8               47.0
# 1994-01-01 01:00:00         9.0               69.0
# ...                         ...                ...
# 2024-11-02 23:00:00        11.0               78.0
# 2024-11-03 00:00:00         6.5               69.0
#
# [270337 rows x 7 columns]

# %%
# Database Connection: We use sql server with a trusted connection and weather as database name
engine = create_engine('mssql+pyodbc://SERVER_NAME/weather?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server')

# %%
# Database load
Tepic_weather_readings.to_sql('weather_readings', engine, if_exists='append', index=False)
# Out:
# 41

# %%
# Filtering needed columns
Tepic_city_codes=Tepic_hourly[['date','time','code', 'city','temperature','dew_point','pressure','wind_speed', 'relative_humidity']]
Tepic_city_codes
# Out:
#                            date      time  code       city  temperature  \
# time
# 1994-01-01 00:00:00  1994-01-01  00:00:00   NaN  Querétaro         24.0
# 1994-01-01 01:00:00  1994-01-01  01:00:00   NaN  Querétaro         21.0
# ...                         ...       ...   ...        ...          ...
# 2024-11-02 23:00:00  2024-11-02  23:00:00   1.0  Querétaro         24.0
# 2024-11-03 00:00:00  2024-11-03  00:00:00   1.0  Querétaro         22.0
#
#                      dew_point  pressure  wind_speed  relative_humidity
# time
# 1994-01-01 00:00:00       12.0    1000.1        14.8               47.0
# 1994-01-01 01:00:00       15.1    1000.1         9.0               69.0
# ...                        ...       ...         ...                ...
# 2024-11-02 23:00:00       19.9    1015.0        11.0               78.0
# 2024-11-03 00:00:00       16.1    1015.0         6.5               69.0
#
# [270337 rows x 9 columns]

# %%
# Database load
Tepic_city_codes.to_sql('w_readings_city_codes', engine, if_exists='append', index=False)
# Out:
# 57
