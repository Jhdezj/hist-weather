# %% [markdown]
# # **ETL**

# %%
# Main libraries

import requests 
import os 
import pandas as pd  
import numpy as np
from datetime import datetime
from meteostat import Point, Daily, Hourly
import sqlalchemy
from sqlalchemy import create_engine

# %%
pd.set_option('display.max_rows', 5)

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## **Weather Readings: Querétaro**

# %% [markdown]
# **Method**: Meteostat Python Library

# %%
Qro_latitude = 20.5875   
Qro_longitude = -100.393  
Qro = Point(Qro_latitude, Qro_longitude)

# %% [markdown]
# **Daily data**

# %%
# Set time period
start = datetime(1994, 1, 1)
end = datetime(2024, 11, 3)

# Get daily data
Qro_daily = Daily(Qro, start, end)
Qro_daily = Qro_daily.fetch()
Qro_daily
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 1994-01-06  -7.7   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN   NaN
# 1994-01-07  -8.3   NaN   NaN   NaN   NaN    NaN   NaN   NaN     NaN   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-11-02  17.8  12.0  26.6   0.0   NaN   99.0  11.2   NaN  1023.9   NaN
# 2024-11-03  18.3  10.0  26.0   0.0   NaN  262.0  12.7   NaN  1022.9   NaN
#
# [11260 rows x 10 columns]

# %% [markdown]
# **Hourly data**

# %%
# Data exploration
Qro_hourly = Hourly(Qro, start, end)
Qro_hourly = Qro_hourly.fetch()
Qro_hourly
# Out:
#                      temp  dwpt  rhum  prcp  snow  wdir  wspd  wpgt    pres  \
# time
# 1994-01-04 21:00:00  -5.6 -16.2  43.0   NaN   NaN  60.0  36.7   NaN  1000.1
# 1994-01-04 22:00:00   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     NaN
# ...                   ...   ...   ...   ...   ...   ...   ...   ...     ...
# 2024-11-02 23:00:00  23.0  10.1  44.0   0.0   NaN  70.0  11.0   NaN  1022.0
# 2024-11-03 00:00:00  21.0   9.9  49.0   0.0   NaN  60.0  13.0   NaN  1023.0
#
#                      tsun  coco
# time
# 1994-01-04 21:00:00   NaN   NaN
# 1994-01-04 22:00:00   NaN   NaN
# ...                   ...   ...
# 2024-11-02 23:00:00   NaN   2.0
# 2024-11-03 00:00:00   NaN   3.0
#
# [270244 rows x 11 columns]

# %%
# Adding columns according to the ER diagram 
Qro_hourly['date']=Qro_hourly.index.date 
Qro_hourly['time']=Qro_hourly.index.time 
Qro_hourly['city']= 'Querétaro'
Qro_hourly
# Out:
#                      temp  dwpt  rhum  prcp  snow  wdir  wspd  wpgt    pres  \
# time
# 1994-01-04 21:00:00  -5.6 -16.2  43.0   NaN   NaN  60.0  36.7   NaN  1000.1
# 1994-01-04 22:00:00   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     NaN
# ...                   ...   ...   ...   ...   ...   ...   ...   ...     ...
# 2024-11-02 23:00:00  23.0  10.1  44.0   0.0   NaN  70.0  11.0   NaN  1022.0
# 2024-11-03 00:00:00  21.0   9.9  49.0   0.0   NaN  60.0  13.0   NaN  1023.0
#
#                      tsun  coco        date      time       city
# time
# 1994-01-04 21:00:00   NaN   NaN  1994-01-04  21:00:00  Querétaro
# 1994-01-04 22:00:00   NaN   NaN  1994-01-04  22:00:00  Querétaro
# ...                   ...   ...         ...       ...        ...
# 2024-11-02 23:00:00   NaN   2.0  2024-11-02  23:00:00  Querétaro
# 2024-11-03 00:00:00   NaN   3.0  2024-11-03  00:00:00  Querétaro
#
# [270244 rows x 14 columns]

# %%
# Renaming columns according to the ER diagram 
Qro_hourly = Qro_hourly.rename(columns={'temp':'temperature','coco':'code', 'dwpt':'dew_point', 'pres':'pressure', 'wspd':'wind_speed','rhum':'relative_humidity'})
Qro_hourly
# Out:
#                      temperature  dew_point  relative_humidity  prcp  snow  \
# time
# 1994-01-04 21:00:00         -5.6      -16.2               43.0   NaN   NaN
# 1994-01-04 22:00:00          NaN        NaN                NaN   NaN   NaN
# ...                          ...        ...                ...   ...   ...
# 2024-11-02 23:00:00         23.0       10.1               44.0   0.0   NaN
# 2024-11-03 00:00:00         21.0        9.9               49.0   0.0   NaN
#
#                      wdir  wind_speed  wpgt  pressure  tsun  code        date  \
# time
# 1994-01-04 21:00:00  60.0        36.7   NaN    1000.1   NaN   NaN  1994-01-04
# 1994-01-04 22:00:00   NaN         NaN   NaN       NaN   NaN   NaN  1994-01-04
# ...                   ...         ...   ...       ...   ...   ...         ...
# 2024-11-02 23:00:00  70.0        11.0   NaN    1022.0   NaN   2.0  2024-11-02
# 2024-11-03 00:00:00  60.0        13.0   NaN    1023.0   NaN   3.0  2024-11-03
#
#                          time       city
# time
# 1994-01-04 21:00:00  21:00:00  Querétaro
# 1994-01-04 22:00:00  22:00:00  Querétaro
# ...                       ...        ...
# 2024-11-02 23:00:00  23:00:00  Querétaro
# 2024-11-03 00:00:00  00:00:00  Querétaro
#
# [270244 rows x 14 columns]

# %%
# Filtering needed columns
Qro_weather_readings=Qro_hourly[['date','time','temperature','dew_point','pressure','wind_speed', 'relative_humidity']]
Qro_weather_readings
# Out:
#                            date      time  temperature  dew_point  pressure  \
# time
# 1994-01-04 21:00:00  1994-01-04  21:00:00         -5.6      -16.2    1000.1
# 1994-01-04 22:00:00  1994-01-04  22:00:00          NaN        NaN       NaN
# ...                         ...       ...          ...        ...       ...
# 2024-11-02 23:00:00  2024-11-02  23:00:00         23.0       10.1    1022.0
# 2024-11-03 00:00:00  2024-11-03  00:00:00         21.0        9.9    1023.0
#
#                      wind_speed  relative_humidity
# time
# 1994-01-04 21:00:00        36.7               43.0
# 1994-01-04 22:00:00         NaN                NaN
# ...                         ...                ...
# 2024-11-02 23:00:00        11.0               44.0
# 2024-11-03 00:00:00        13.0               49.0
#
# [270244 rows x 7 columns]

# %%
# Database Connection: We use sql server with a trusted connection and weather as database name
engine = create_engine('mssql+pyodbc://SERVER_NAME/weather?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server')

# %%
# Database load
Qro_weather_readings.to_sql('weather_readings', engine, if_exists='append', index=False)
# Out:
# 247

# %%
# Filtering needed columns
Qro_city_codes=Qro_hourly[['date','time','code', 'city','temperature','dew_point','pressure','wind_speed', 'relative_humidity']]
Qro_city_codes
# Out:
#                            date      time  code       city  temperature  \
# time
# 1994-01-04 21:00:00  1994-01-04  21:00:00   NaN  Querétaro         -5.6
# 1994-01-04 22:00:00  1994-01-04  22:00:00   NaN  Querétaro          NaN
# ...                         ...       ...   ...        ...          ...
# 2024-11-02 23:00:00  2024-11-02  23:00:00   2.0  Querétaro         23.0
# 2024-11-03 00:00:00  2024-11-03  00:00:00   3.0  Querétaro         21.0
#
#                      dew_point  pressure  wind_speed  relative_humidity
# time
# 1994-01-04 21:00:00      -16.2    1000.1        36.7               43.0
# 1994-01-04 22:00:00        NaN       NaN         NaN                NaN
# ...                        ...       ...         ...                ...
# 2024-11-02 23:00:00       10.1    1022.0        11.0               44.0
# 2024-11-03 00:00:00        9.9    1023.0        13.0               49.0
#
# [270244 rows x 9 columns]

# %%
# Database load
Qro_city_codes.to_sql('w_readings_city_codes', engine, if_exists='append', index=False)
# Out:
# 197
